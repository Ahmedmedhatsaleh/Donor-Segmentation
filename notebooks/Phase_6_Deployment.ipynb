# %% [markdown]
# # Phase 6: Deployment
#
# **CRISP-DM Phase Description:**
# The final phase involves organising and presenting the project findings so that the customer can use them, or integrating the model into a live production system. Depending on the requirements, deployment can range from generating a simple report to implementing a repeatable data mining process across the enterprise.
#
# ---

# %%
# Standard imports
import pandas as pd
import numpy as np
import json

# %% [markdown]
# ---
# ### Task 1: Plan Deployment
#
# Develop a strategy for putting the data mining results to practical use. This includes:
#
# - **Deployment Strategy:** How will the model be consumed? Options include a REST API, a batch prediction script, an interactive dashboard, or integration into an existing software system.
# - **Infrastructure Requirements:** What technical environment is needed (e.g., cloud services, web server, containerisation)?
# - **Steps to Deploy:** List the concrete, ordered steps needed to move from a trained model to a live, usable product.
# - **User Training:** Will end-users need instructions or documentation to use the deployed solution?
#
# **Instructions:** Outline your deployment plan as a structured dictionary. If building an API or script, sketch the basic structure in code.

# %%
deployment_plan = {
    "strategy": "Batch Script",

    "infrastructure": [
        "Python environment with pandas, scikit-learn, joblib, numpy",
        "Jupyter Notebook or Python script for batch predictions",
        "Local machine or cloud infrastructure for scalability (e.g., AWS, Google Cloud, etc.)",
        "Saved trained model file using joblib or pickle",
        "Access to project application data (via file upload or integration)"
    ],

    "deployment_steps": [
        "Step 1: Select the best trained model from Phase 4 (Logistic Regression)",
        "Step 2: Save the trained model to a file using joblib or pickle for persistence",
        "Step 3: Prepare new input data using the same preprocessing steps as training",
        "Step 4: Load the saved model into a Python script or notebook",
        "Step 5: Generate predictions on new project application data",
        "Step 6: Export prediction results (e.g., to CSV or a database for decision support)",
        "Step 7: Validate predictions before practical use (ensure data consistency and model's reliability)",
        "Step 8: Monitor model performance in real-world applications and update periodically"
    ],

    "user_documentation": """
        A short user guide will explain how to:
        - Load the model using joblib or pickle
        - Prepare new project application data with the same preprocessing steps
        - Run predictions using the trained model
        - Interpret the results (i.e., approval probabilities)
    """,

    "target_audience": "Business analysts, education stakeholders, and decision-makers reviewing project approval outcomes, with emphasis on non-technical users for easy consumption of results.",

    "technical_requirements": """
        - Ensure the Python environment is set up with required dependencies (pandas, numpy, scikit-learn, joblib)
        - Consider deploying as a containerized solution (e.g., Docker) for flexibility and easy scaling
        - Prepare for the deployment on cloud services (AWS, Azure) if needed for larger scale or automation
    """
}

# %%
# Optional: Sketch a basic deployment script or API structure

# Example: Saving the trained model for deployment
# import joblib
# MODEL_PATH = 'path/to/your/saved_model.pkl'
# joblib.dump(best_model, MODEL_PATH)
# print(f"Model saved to: {MODEL_PATH}")

# Example: Basic prediction function skeleton
# def predict(input_data: dict) -> dict:
#     """
#     Takes a dictionary of feature values,
#     returns the model's prediction.
#     """
#     model = joblib.load(MODEL_PATH)
#     input_df = pd.DataFrame([input_data])
#     prediction = model.predict(input_df)
#     return {"prediction": prediction.tolist()}

# %%
# Display the deployment plan

print(json.dumps(deployment_plan, indent=2))
# Out:
# {
#   "strategy": "Batch Script",
#   "infrastructure": [
#     "Python environment with pandas, scikit-learn, joblib, numpy",
#     "Jupyter Notebook or Python script for batch predictions",
#     "Local machine or cloud infrastructure for scalability (e.g., AWS, Google Cloud, etc.)",
#     "Saved trained model file using joblib or pickle",
#     "Access to project application data (via file upload or integration)"
#   ],
#   "deployment_steps": [
#     "Step 1: Select the best trained model from Phase 4 (Logistic Regression)",
#     "Step 2: Save the trained model to a file using joblib or pickle for persistence",
#     "Step 3: Prepare new input data using the same preprocessing steps as training",
#     "Step 4: Load the saved model into a Python script or notebook",
#     "Step 5: Generate predictions on new project application data",
#     "Step 6: Export prediction results (e.g., to CSV or a database for decision support)",
# ...

# %% [markdown]
# ---
# ### Task 2: Plan Monitoring and Maintenance
#
# A deployed model is not "set and forget". Over time, the data distribution may shift (**data drift**) or the model's performance may degrade (**model decay**). This task creates a monitoring and maintenance plan:
#
# - **Performance Monitoring:** How and how often will the model's predictions be evaluated against actuals?
# - **Data Drift Detection:** How will changes in the input data distribution be detected?
# - **Retraining Strategy:** Under what conditions will the model be retrained (e.g., scheduled, triggered by performance drop)?
# - **Logging and Alerting:** What will be logged, and what triggers an alert?
#
# **Instructions:** Document your monitoring and maintenance plan.

# %%
# TODO: Plan monitoring and maintenance.

monitoring_plan = {
    "performance_monitoring": {
        "frequency": "Monthly",
        "metrics_tracked": ["Accuracy", "Precision", "Recall", "F1-Score"],
        "method": "Compare model predictions with actual project approval outcomes once true labels become available."
    },

    "data_drift_detection": {
        "method": "Monitor changes in input feature distributions by comparing new data against the training data using summary statistics, category frequency checks, and trend comparisons.",
        "frequency": "Monthly",
        "threshold": "Investigate the model if major feature distribution changes are detected or if predictive performance declines noticeably."
    },

    "retraining_strategy": {
        "trigger": "Retrain the model if weighted F1-score drops below 0.75 or if clear data drift is identified.",
        "data_source": "Latest available DonorsChoose project application data",
        "responsible_team": "Data analyst or project owner"
    },

    "logging_and_alerting": {
        "what_to_log": ["Input features", "Predictions", "Prediction date", "Model version"],
        "alert_conditions": ["F1-score below 0.75", "Significant change in incoming data patterns", "Repeated prediction failures or invalid inputs"]
    }
}

print("  MONITORING AND MAINTENANCE PLAN ")
for section, details in monitoring_plan.items():
    print(f"\n{section.upper()}:")
    print(details)
# Out:
#   MONITORING AND MAINTENANCE PLAN
#
# PERFORMANCE_MONITORING:
# {'frequency': 'Monthly', 'metrics_tracked': ['Accuracy', 'Precision', 'Recall', 'F1-Score'], 'method': 'Compare model predictions with actual project approval outcomes once true labels become available.'}
#
# DATA_DRIFT_DETECTION:
# {'method': 'Monitor changes in input feature distributions by comparing new data against the training data using summary statistics, category frequency checks, and trend comparisons.', 'frequency': 'Monthly', 'threshold': 'Investigate the model if major feature distribution changes are detected or if predictive performance declines noticeably.'}
#
# RETRAINING_STRATEGY:
# {'trigger': 'Retrain the model if weighted F1-score drops below 0.75 or if clear data drift is identified.', 'data_source': 'Latest available DonorsChoose project application data', 'responsible_team': 'Data analyst or project owner'}
#
# LOGGING_AND_ALERTING:
# ...

# %%
# Display the monitoring plan

print(json.dumps(monitoring_plan, indent=2))
# Out:
# {
#   "performance_monitoring": {
#     "frequency": "Monthly",
#     "metrics_tracked": [
#       "Accuracy",
#       "Precision",
#       "Recall",
#       "F1-Score"
#     ],
#     "method": "Compare model predictions with actual project approval outcomes once true labels become available."
#   },
#   "data_drift_detection": {
#     "method": "Monitor changes in input feature distributions by comparing new data against the training data using summary statistics, category frequency checks, and trend comparisons.",
#     "frequency": "Monthly",
#     "threshold": "Investigate the model if major feature distribution changes are detected or if predictive performance declines noticeably."
#   },
#   "retraining_strategy": {
#     "trigger": "Retrain the model if weighted F1-score drops below 0.75 or if clear data drift is identified.",
#     "data_source": "Latest available DonorsChoose project application data",
#     "responsible_team": "Data analyst or project owner"
#   },
# ...

# %% [markdown]
# ---
# ### Task 3: Produce Final Report
#
# Compile a final summary of the entire project. This report should communicate the findings to stakeholders who may not have a technical background. It typically includes:
#
# - **Executive Summary:** A brief overview of the problem, approach, and key results.
# - **Key Findings:** The most important patterns, insights, and model performance results.
# - **Visualisations:** Charts and plots that support the findings (suitable for a presentation).
# - **Recommendations:** Actionable recommendations based on the analysis.
# - **Limitations:** Known limitations and caveats of the analysis.
#
# **Instructions:** Draft the final report content below. Include any code needed to generate summary visualisations.

# %%
final_report = {
    "title": "Donor Segmentation and retention",
    
    "executive_summary": "This project applied the CRISP-DM methodology to analyse donor behaviour using both segmentation and regression techniques. The process included business understanding, data exploration, preparation, modelling, evaluation, and deployment planning. Donor segmentation was used to group donors into meaningful clusters based on shared behavioural and numerical characteristics, while regression was used to predict donation-related outcomes. The analysis revealed clear differences between donor groups and showed that predictive modelling can support better fundraising decisions. Overall, the project demonstrated how data-driven methods can help nonprofit organisations improve donor targeting, retention, and strategic planning.",
    
    "key_findings": [
        "Donor segmentation identified distinct groups with different engagement and contribution patterns.",
        "Some donor segments showed stronger value and retention potential than others.",
        "Regression modelling captured useful patterns in donation-related behaviour using the available features.",
        "Data preprocessing, feature selection, and scaling were important for improving model quality.",
        "The CRISP-DM framework provided a structured approach from business understanding to evaluation and future deployment planning."
    ],
    
    "model_performance": {
        "segmentation": {
            "method": "K-Means Clustering",
            "evaluation": "Elbow method, silhouette score, and interpretation of cluster characteristics"
        },
        "regression": {
            "method": "Regression model",
            "metrics": {
                "MAE": "Calculated from model output",
                "RMSE": "Calculated from model output",
                "R2": "Calculated from model output"
            },
            "justification": "The regression model was used to estimate donation-related outcomes and support forecasting and donor value analysis."
        }
    },
    
    "recommendations": [
        "Use donor segments to design more targeted fundraising and retention campaigns.",
        "Prioritise high-value donor groups for long-term engagement strategies.",
        "Use regression outputs to support donation forecasting and resource planning.",
        "Continue improving the model through feature engineering, tuning, and updated donor data.",
        "Apply ethical and fairness checks before using the models in real decision-making settings."
    ],
    
    "limitations": [
        "The dataset may not capture all factors influencing donor behaviour and donation outcomes.",
        "Cluster interpretation can be subjective and may vary depending on the selected features.",
        "Regression performance depends on data quality, feature relevance, and the assumptions of the chosen model.",
        "The models have not yet been tested in a real deployment environment.",
        "Performance may change over time if donor behaviour patterns shift."
    ]
}

# %%
print("=" * 60)
print(f"FINAL REPORT: {final_report['title']}")
print("=" * 60)

print("\n--- Executive Summary ---")
print(final_report['executive_summary'])

print("\n--- Key Findings ---")
for i, f in enumerate(final_report['key_findings'], 1):
    print(f"  {i}. {f}")

print("\n--- Recommendations ---")
for i, r in enumerate(final_report['recommendations'], 1):
    print(f"  {i}. {r}")

print("\n--- Limitations ---")
for i, l in enumerate(final_report['limitations'], 1):
    print(f"  {i}. {l}")
# Out:
# ...
# FINAL REPORT: Donor Segmentation and retention
# ...
#
# --- Executive Summary ---
# This project applied the CRISP-DM methodology to analyse donor behaviour using both segmentation and regression techniques. The process included business understanding, data exploration, preparation, modelling, evaluation, and deployment planning. Donor segmentation was used to group donors into meaningful clusters based on shared behavioural and numerical characteristics, while regression was used to predict donation-related outcomes. The analysis revealed clear differences between donor groups and showed that predictive modelling can support better fundraising decisions. Overall, the project demonstrated how data-driven methods can help nonprofit organisations improve donor targeting, retention, and strategic planning.
#
# --- Key Findings ---
#   1. Donor segmentation identified distinct groups with different engagement and contribution patterns.
# ...

# %%
import matplotlib.pyplot as plt

models = ["Logistic Regression", "Random Forest", "Gradient Boosting"]
scores = [0.7814, 0.7739, 0.7785]

plt.figure(figsize=(8, 5))
plt.bar(models, scores, edgecolor='black')
plt.title("Model Performance Comparison", fontsize=14)
plt.ylabel("F1-Score")
plt.ylim(0, 1)

for i, v in enumerate(scores):
    plt.text(i, v + 0.02, f"{v:.4f}", ha='center', fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ### Task 4: Review Project
#
# Conduct a project retrospective. Reflect on what went well, what did not go as planned, and what lessons can be carried forward to future projects.
#
# - **What went well?** Successes, effective techniques, good decisions.
# - **What could be improved?** Challenges, mistakes, or inefficiencies encountered.
# - **Lessons learned:** Key takeaways for future data science projects.
# - **Skills developed:** New skills or knowledge gained during the project.
#
# **Instructions:** Complete the project retrospective below.

# %%
project_retrospective = {
    "went_well": [
        "The CRISP-DM framework provided a clear and organised structure throughout the project.",
        "Data preparation and preprocessing improved the quality and usability of the dataset.",
        "Both segmentation and regression techniques were successfully applied to analyse donor behaviour.",
        "The project produced meaningful insights into donor patterns and potential donation trends."
    ],
    
    "could_improve": [
        "More optimisation of the clustering process, such as better selection of the number of clusters, could improve results.",
        "Additional feature engineering may improve both segmentation quality and regression performance.",
        "Further evaluation metrics (e.g., silhouette score, RMSE) could be explored in more depth.",
        "The models could be tested in a more realistic or real-time deployment environment."
    ],
    
    "lessons_learned": [
        "Clustering can reveal hidden patterns in data that are not visible through simple analysis.",
        "Regression models help in understanding and predicting continuous outcomes rather than classification labels.",
        "Data preprocessing and feature scaling are essential for improving model performance.",
        "The CRISP-DM lifecycle is iterative, and refining earlier stages is a normal part of the process."
    ],
    
    "skills_developed": [
        "Data cleaning and preprocessing",
        "Clustering techniques (e.g., K-Means)",
        "Regression modelling using machine learning",
        "Model evaluation using appropriate metrics",
        "Critical analysis and interpretation of data science results"
    ]
}

# %%
# Display the retrospective

print("=" * 60)
print("PROJECT RETROSPECTIVE")
print("=" * 60)

sections = [
    ("What Went Well", project_retrospective['went_well']),
    ("What Could Be Improved", project_retrospective['could_improve']),
    ("Lessons Learned", project_retrospective['lessons_learned']),
    ("Skills Developed", project_retrospective['skills_developed']),
]

for section_name, items in sections:
    print(f"\n--- {section_name} ---")
    if items:
        for item in items:
            print(f" - {item}")
    else:
        print(" [Not yet documented]")
# Out:
# ...
# PROJECT RETROSPECTIVE
# ...
#
# --- What Went Well ---
#  - The CRISP-DM framework provided a clear and organised structure throughout the project.
#  - Data preparation and preprocessing improved the quality and usability of the dataset.
#  - Both segmentation and regression techniques were successfully applied to analyse donor behaviour.
#  - The project produced meaningful insights into donor patterns and potential donation trends.
#
# --- What Could Be Improved ---
#  - More optimisation of the clustering process, such as better selection of the number of clusters, could improve results.
#  - Additional feature engineering may improve both segmentation quality and regression performance.
#  - Further evaluation metrics (e.g., silhouette score, RMSE) could be explored in more depth.
#  - The models could be tested in a more realistic or real-time deployment environment.
#
# --- Lessons Learned ---
# ...

# %% [markdown]
# ---
#
# ## Key Takeaway on Iteration
#
# While the six CRISP-DM phases are presented **sequentially** in these notebooks, in practice the process is **highly iterative**. Real-world data science projects rarely follow a straight line from Phase 1 to Phase 6.
#
# Common iteration patterns include:
#
# - **Modelling → Data Preparation:** If the model performs poorly, you may return to Phase 3 to engineer new features, clean data differently, or acquire more data.
# - **Evaluation → Modelling:** If the model does not meet the business success criteria, you may go back to Phase 4 to try different algorithms or tune hyperparameters.
# - **Deployment → Evaluation:** If the deployed model underperforms in production (data drift), you may return to Phase 5 to re-evaluate and then to Phase 3/4 to retrain.
# - **Any Phase → Business Understanding:** New findings in later phases may redefine the business objectives or success criteria originally set in Phase 1.
#
# ```
# ┌───────────────────────────────────────────────────────────┐
# │                     CRISP-DM Lifecycle                    │
# │                                                           │
# │   Phase 1 ──► Phase 2 ──► Phase 3 ──► Phase 4            │
# │   Business    Data        Data        Modelling           │
# │   Under.      Under.      Prep.           │               │
# │     ▲                       ▲              │               │
# │     │                       │              ▼               │
# │     │                       └──────── Phase 5             │
# │     │                                Evaluation           │
# │     │                                    │                │
# │     │                                    ▼                │
# │     └──────────────────────────────  Phase 6              │
# │                                     Deployment            │
# └───────────────────────────────────────────────────────────┘
# ```
#
# > **Remember:** Iteration is not failure — it is the *expected* workflow. Each cycle through the process deepens your understanding of both the data and the business problem, ultimately leading to a better solution.
