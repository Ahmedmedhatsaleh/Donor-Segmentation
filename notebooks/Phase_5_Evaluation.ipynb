# %% [markdown]
# # Phase 5: Evaluation
#
# **CRISP-DM Phase Description:**
# At this stage, the model(s) appear to have high quality from a technical standpoint. Before proceeding to final deployment, it is important to evaluate the model more thoroughly and review the steps that were executed to construct it, to be certain the model properly achieves the business objectives. A key objective is to determine if there is some important business issue that has not been sufficiently considered.
#
# ---

# %%
# Standard imports
import pandas as pd
import numpy as np

# %% [markdown]
# ---
# ### Task 1: Evaluate Results
#
# Assess how well the model(s) meet the **business success criteria** originally defined in **Phase 1 (Business Understanding)**. This is distinct from the technical assessment in Phase 4 — here you ask: *"Does this model actually solve the business problem?"*
#
# Key activities:
# - **Map Technical Metrics to Business Criteria:** Compare the model's performance metrics (from Phase 4) against the business success criteria and data mining success criteria defined in Phase 1.
# - **Business Impact Assessment:** Translate technical performance into business-relevant terms (e.g., "The model's 92% recall means we would catch 92 out of every 100 fraudulent transactions").
# - **Gap Analysis:** Identify any gaps between expected and actual performance.
# - **Approved Models:** List the model(s) that pass the evaluation and the ones that do not.
#
# **Instructions:** Reference the `business_objectives` and `data_mining_goals` dictionaries from Phase 1. Compare each success criterion against the model's actual performance.

# %%
# TODO: Evaluate model results against business success criteria.
# Reference your Phase 1 definitions and Phase 4 results.

evaluation = {
    "business_criteria": [
        {
            "criterion": "Accurately predict project approval outcomes",
            "target": "High predictive performance (F1-score close to or above 0.80)",
            "achieved": "Model achieved an F1-score of 0.7814 using Logistic Regression",
            "met": False
        },
        {
            "criterion": "Improve decision-making for funding allocation",
            "target": "Balanced precision and recall for approval prediction",
            "achieved": "Precision = 0.7835 and Recall = 0.8476",
            "met": True
        }
    ],

    "technical_criteria": [
        {
            "metric": "F1-Score",
            "target": ">= 0.80",
            "achieved": 0.7814,
            "met": False
        },
        {
            "metric": "Recall",
            "target": ">= 0.75",
            "achieved": 0.8476,
            "met": True
        }
    ],

    "overall_assessment": "Logistic Regression achieved the best overall performance among the tested models. Although the F1-score is slightly below the target of 0.80, the recall is strong and the model is still useful for decision support.",

    "approved_models": ["Logistic Regression"],
    "rejected_models": ["Random Forest", "Gradient Boosting"]
}

# %%
# Display the evaluation summary
print("=" * 60)
print("EVALUATION AGAINST BUSINESS SUCCESS CRITERIA")
print("=" * 60)

print("\n--- Business Criteria ---")
for c in evaluation['business_criteria']:
    status = 'PASS' if c['met'] else 'FAIL'
    print(f"  [{status}] {c['criterion']}")
    print(f"         Target: {c['target']}  |  Achieved: {c['achieved']}")

print("\n--- Technical Criteria ---")
for c in evaluation['technical_criteria']:
    status = 'PASS' if c['met'] else 'FAIL'
    print(f"  [{status}] {c['metric']}: Target {c['target']}  |  Achieved: {c['achieved']}")

print(f"\nOverall: {evaluation['overall_assessment']}")
print(f"Approved models: {evaluation['approved_models']}")
print(f"Rejected models: {evaluation['rejected_models']}")
# Out:
# ============================================================
# EVALUATION AGAINST BUSINESS SUCCESS CRITERIA
# ============================================================
#
# --- Business Criteria ---
#   [FAIL] Accurately predict project approval outcomes
#          Target: High predictive performance (F1-score close to or above 0.80)  |  Achieved: Model achieved an F1-score of 0.7814 using Logistic Regression
#   [PASS] Improve decision-making for funding allocation
#          Target: Balanced precision and recall for approval prediction  |  Achieved: Precision = 0.7835 and Recall = 0.8476
#
# --- Technical Criteria ---
#   [FAIL] F1-Score: Target >= 0.80  |  Achieved: 0.7814
#   [PASS] Recall: Target >= 0.75  |  Achieved: 0.8476
#
# Overall: Logistic Regression achieved the best overall performance among the tested models. Although the F1-score is slightly below the target of 0.80, the recall is strong and the model is still useful for decision support.
# Approved models: ['Logistic Regression']
# Rejected models: ['Random Forest', 'Gradient Boosting']

# %% [markdown]
# ---
# ### Task 2: Review Process
#
# Conduct a thorough review of the entire CRISP-DM process executed so far. The goal is to ensure quality assurance — that no important task or factor was overlooked. Consider:
#
# - **Completeness Check:** Were all relevant data sources considered? Were the data preparation steps sufficient?
# - **Methodology Review:** Were appropriate techniques used at each stage? Were there alternatives worth exploring?
# - **Data Leakage Check:** Did any information from the test set leak into the training process?
# - **Bias and Fairness:** Could the model introduce or amplify any biases? Is the model fair across different subgroups?
# - **Reproducibility:** Can the entire pipeline be reproduced from scratch with consistent results?
#
# **Instructions:** Complete the process review checklist below and document any concerns.

# %%
process_review = {
    "checklist": [
        {
            "item": "All relevant data sources were considered",
            "status": "Yes",
            "notes": "The DonorsChoose Application Screening dataset from Kaggle was used as the main and only source."
        },
        {
            "item": "Data preparation was thorough and documented",
            "status": "Yes",
            "notes": "Missing values, duplicates, outliers, encoding, scaling, and formatting were addressed in Phase 3."
        },
        {
            "item": "No data leakage between train and test sets",
            "status": "Partial",
            "notes": "The train-test split was applied correctly, but feature scaling was performed before splitting, which introduces a small risk of data leakage."
        },
        {
            "item": "Multiple modelling techniques were compared",
            "status": "Yes",
            "notes": "Logistic Regression, Random Forest, and Gradient Boosting were trained and evaluated."
        },
        {
            "item": "Hyperparameters were tuned appropriately",
            "status": "Partial",
            "notes": "Basic model settings were used. Limited tuning was performed, but more extensive optimisation could improve results."
        },
        {
            "item": "Results are reproducible",
            "status": "Yes",
            "notes": "Random seeds were used in the train-test split and model training where applicable."
        },
        {
            "item": "Bias and fairness were considered",
            "status": "Partial",
            "notes": "Ethical considerations were discussed, but no formal fairness analysis across subgroups was carried out."
        },
        {
            "item": "Ethical implications were reviewed",
            "status": "Yes",
            "notes": "The model is positioned as a decision-support tool rather than a fully automated decision-maker."
        }
    ],

    "overall_quality": "Good overall quality with some methodological limitations and opportunities for improvement.",

    "areas_for_improvement": [
        "Apply scaling after the train-test split to fully avoid data leakage.",
        "Use more advanced hyperparameter tuning such as GridSearchCV.",
        "Perform a fairness analysis across relevant subgroups such as project categories or school states.",
        "Expand feature engineering to improve predictive performance."
    ]
}

print("  PROCESS REVIEW  ")
for item in process_review["checklist"]:
    print(f"[{item['status']:^8}] {item['item']}")
    print(f"   Notes: {item['notes']}")

print(f"\nOverall Quality: {process_review['overall_quality']}")

print("\nAreas for Improvement:")
for improvement in process_review["areas_for_improvement"]:
    print(f"- {improvement}")
# Out:
#   PROCESS REVIEW
# [  Yes   ] All relevant data sources were considered
#    Notes: The DonorsChoose Application Screening dataset from Kaggle was used as the main and only source.
# [  Yes   ] Data preparation was thorough and documented
#    Notes: Missing values, duplicates, outliers, encoding, scaling, and formatting were addressed in Phase 3.
# [Partial ] No data leakage between train and test sets
#    Notes: The train-test split was applied correctly, but feature scaling was performed before splitting, which introduces a small risk of data leakage.
# [  Yes   ] Multiple modelling techniques were compared
#    Notes: Logistic Regression, Random Forest, and Gradient Boosting were trained and evaluated.
# [Partial ] Hyperparameters were tuned appropriately
#    Notes: Basic model settings were used. Limited tuning was performed, but more extensive optimisation could improve results.
# [  Yes   ] Results are reproducible
#    Notes: Random seeds were used in the train-test split and model training where applicable.
# [Partial ] Bias and fairness were considered
#    Notes: Ethical considerations were discussed, but no formal fairness analysis across subgroups was carried out.
# [  Yes   ] Ethical implications were reviewed
#    Notes: The model is positioned as a decision-support tool rather than a fully automated decision-maker.
#
# Overall Quality: Good overall quality with some methodological limitations and opportunities for improvement.
#
# Areas for Improvement:
# - Apply scaling after the train-test split to fully avoid data leakage.
# - Use more advanced hyperparameter tuning such as GridSearchCV.
# - Perform a fairness analysis across relevant subgroups such as project categories or school states.
# - Expand feature engineering to improve predictive performance.

# %%
# Display the process review
print("  Process Review Checklist  ")
for item in process_review['checklist']:
    print(f"  [{item['status']:^8}] {item['item']}")
    if item['notes']:
        print(f"           Note: {item['notes']}")

print(f"\nOverall Quality: {process_review['overall_quality']}")
if process_review['areas_for_improvement']:
    print("Areas for Improvement:")
    for area in process_review['areas_for_improvement']:
        print(f"  - {area}")
# Out:
#   Process Review Checklist
#   [  Yes   ] All relevant data sources were considered
#            Note: The DonorsChoose Application Screening dataset from Kaggle was used as the main and only source.
#   [  Yes   ] Data preparation was thorough and documented
#            Note: Missing values, duplicates, outliers, encoding, scaling, and formatting were addressed in Phase 3.
#   [Partial ] No data leakage between train and test sets
#            Note: The train-test split was applied correctly, but feature scaling was performed before splitting, which introduces a small risk of data leakage.
#   [  Yes   ] Multiple modelling techniques were compared
#            Note: Logistic Regression, Random Forest, and Gradient Boosting were trained and evaluated.
#   [Partial ] Hyperparameters were tuned appropriately
#            Note: Basic model settings were used. Limited tuning was performed, but more extensive optimisation could improve results.
#   [  Yes   ] Results are reproducible
#            Note: Random seeds were used in the train-test split and model training where applicable.
#   [Partial ] Bias and fairness were considered
#            Note: Ethical considerations were discussed, but no formal fairness analysis across subgroups was carried out.
#   [  Yes   ] Ethical implications were reviewed
#            Note: The model is positioned as a decision-support tool rather than a fully automated decision-maker.
#
# Overall Quality: Good overall quality with some methodological limitations and opportunities for improvement.
# Areas for Improvement:
#   - Apply scaling after the train-test split to fully avoid data leakage.
#   - Use more advanced hyperparameter tuning such as GridSearchCV.
#   - Perform a fairness analysis across relevant subgroups such as project categories or school states.
#   - Expand feature engineering to improve predictive performance.

# %% [markdown]
# ---
# ### Task 3: Determine Next Steps
#
# Based on the evaluation results and process review, decide on the next course of action. The three main options are:
#
# 1. **Proceed to Deployment:** The model meets all criteria and is ready for deployment.
# 2. **Iterate:** Go back to a previous phase (e.g., Data Preparation or Modelling) to improve the model before deployment.
# 3. **Terminate:** The project is not viable in its current form and should be re-scoped or abandoned.
#
# **Instructions:** Document your decision and provide a clear rationale.

# %%
# TODO: Determine and document the next steps.

next_steps = {
    "decision": "Iterate Further",

    "rationale": "The best model, Logistic Regression, achieved the highest F1-score among the tested models, but its F1-score of 0.7814 is slightly below the target of 0.80. This means the model is useful, but further improvement is needed before deployment.",

    "if_iterating": {
        "return_to_phase": "Phase 4 - Modeling",
        "specific_actions": [
            "Tune model hyperparameters more thoroughly",
            "Try additional classification models",
            "Improve feature engineering to raise the F1-score"
        ]
    },

    "if_deploying": {
        "selected_model": "",
        "deployment_priority": ""
    }
}

# %%
print("=== Recommended Next Steps ===")
print(f"Decision: {next_steps['decision']}")
print(f"Rationale: {next_steps['rationale']}")

if next_steps['decision'] == "Iterate Further":
    print(f"Return to: {next_steps['if_iterating']['return_to_phase']}")
    print("Specific Actions:")
    for action in next_steps['if_iterating']['specific_actions']:
        print(f"  - {action}")

elif next_steps['decision'] == "Proceed to Deployment":
    print(f"Deploy Model: {next_steps['if_deploying']['selected_model']}")
    print(f"Priority: {next_steps['if_deploying']['deployment_priority']}")
# Out:
# === Recommended Next Steps ===
# Decision: Iterate Further
# Rationale: The best model, Logistic Regression, achieved the highest F1-score among the tested models, but its F1-score of 0.7814 is slightly below the target of 0.80. This means the model is useful, but further improvement is needed before deployment.
# Return to: Phase 4 - Modeling
# Specific Actions:
#   - Tune model hyperparameters more thoroughly
#   - Try additional classification models
#   - Improve feature engineering to raise the F1-score
