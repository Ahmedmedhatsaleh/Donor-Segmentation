# %% [markdown]
# # Phase 1: Business Understanding
#
# **CRISP-DM Phase Description:**
# This phase focuses on understanding the project objectives and requirements from a business perspective, then converting this knowledge into a data mining problem definition and a preliminary plan designed to achieve the objectives.
#
# ---

# %% [markdown]
# ### Task 1: Determine Business Objectives
#
# The first objective of the data analyst is to thoroughly understand, from a business perspective, what the customer really wants to accomplish. This involves:
#
# - **Background:** Identify the organisational context and the business area the project relates to.
# - **Business Objectives:** Clearly state the primary question or problem the business wants to solve.
# - **Business Success Criteria:** Define the measurable criteria that determine whether the project's outcome is considered a success from the business's point of view (e.g., "reduce customer churn by 15%", "improve prediction accuracy to 90%").
#
# **Instructions:** In the cells below, define your business objectives, background context, and success criteria as Python variables (strings or dictionaries). This ensures your business logic is documented directly in the notebook's code state.

# %%
# TODO: Define business objectives here.
# Example:
# business_objectives = {
#     "background": "Describe the organisational context and business area...",
#     "primary_objective": "What is the main business question or problem?",
#     "success_criteria": [
#         "Criterion 1: e.g., Reduce X by Y%",
#         "Criterion 2: e.g., Achieve Z accuracy"
#     ]
# }


business_objectives = {
    "background": "Non-profit organizations rely heavily on donor funding to support projects. However, not all projects receive equal attention or funding, which impacts donor engagement and long-term retention. Understanding which types of projects are more likely to be successfully funded can help organizations better align their strategies with donor preferences. This project uses the DonorsChoose dataset to analyse patterns in project success and infer insights that can support donor segmentation and retention strategies.",
    
    "primary_objective": "To analyse the factors that influence whether a project is approved (funded) and use these insights to support donor segmentation and retention strategies by identifying the types of projects that are more likely to attract consistent donor support.",
    
    "success_criteria": [
        "Develop a classification model that predicts project approval with strong performance.",
        "Identify key features that influence project success and donor engagement.",
        "Provide actionable insights that can help improve donor targeting and retention strategies.",
        "Demonstrate clear patterns between project characteristics (like cost and category and approval outcomes."
    ]
}

# %%
# Display the defined objectives in a readable format
for key, value in business_objectives.items():
    print(f">> {key.upper().replace('_', ' ')}:")
    if isinstance(value, list):
        for item in value:
            print(f"   - {item}")
    else:
        print(f"   {value}")
    print()
# Out:
# >> BACKGROUND:
#    Non-profit organizations rely heavily on donor funding to support projects. However, not all projects receive equal attention or funding, which impacts donor engagement and long-term retention. Understanding which types of projects are more likely to be successfully funded can help organizations better align their strategies with donor preferences. This project uses the DonorsChoose dataset to analyse patterns in project success and infer insights that can support donor segmentation and retention strategies.
#
# >> PRIMARY OBJECTIVE:
#    To analyse the factors that influence whether a project is approved (funded) and use these insights to support donor segmentation and retention strategies by identifying the types of projects that are more likely to attract consistent donor support.
#
# >> SUCCESS CRITERIA:
#    - Develop a classification model that predicts project approval with strong performance.
# ...

# %% [markdown]
# ---
# ### Task 2: Assess Situation
#
# This task involves a more detailed fact-finding about all of the resources, constraints, assumptions, and other factors that should be considered in determining the data analysis goal and project plan. Key areas to assess:
#
# - **Resources Inventory:** Personnel, data sources, computing resources, and software available.
# - **Requirements, Assumptions, and Constraints:** Project schedule, legal/ethical considerations, data access limitations, and budget.
# - **Risks and Contingencies:** Identify potential risks (e.g., data unavailability, quality issues, privacy concerns) and how to mitigate them.
# - **Terminology Glossary:** Define key domain-specific terms relevant to the project.
# - **Costs and Benefits:** A cost-benefit analysis of the project.
#
# **Instructions:** Document your situation assessment as a structured dictionary or set of variables.

# %%
# TODO: Assess the current situation here.
# Document resources, requirements, assumptions, constraints, and risks.


situation_assessment = {
    "resources": {
        "personnel": ["Individual student researcher", "Domain knowledge from academic articles and module materials"],
        "data_sources": ["DonorsChoose Application Screening dataset from Kaggle"],
        "computing": "Local machine with Anaconda environment and Jupyter Notebook support",
        "software": ["Python", "pandas", "NumPy", "scikit-learn", "matplotlib", "seaborn"]
    },

    "requirements": [
        "Access to a sufficiently large dataset related to non-profit project funding",
        "Ability to preprocess structured and categorical data for modelling",
        "Compliance with ethical and privacy considerations when working with public datasets",
    ],

    "assumptions": [
        "The DonorsChoose dataset is representative of project funding patterns in a non-profit context",
        "Project approval can be used as an indicator of successful donor support",
        "Historical project and resource features can help explain future funding outcomes"
    ],

    "constraints": [
        "The dataset does not contain detailed donor-level retention history",
        "Limited computational resources compared to large-scale industry big data platforms",
        "Possible missing, noisy, or imbalanced data",
        "Time limitations due to the assignment schedule"
    ],

    "risks_and_contingencies": [
        {
            "risk": "Data quality issues such as missing values, outliers, or inconsistent categories",
            "probability": "Medium",
            "mitigation": "Apply data cleaning, preprocessing, and validation before modelling"
        },
        {
            "risk": "Model underperformance or class imbalance",
            "probability": "Medium",
            "mitigation": "Evaluate multiple models using suitable metrics such as F1-score and use cross-validation"
        },
        {
            "risk": "Limited alignment between assigned topic and available dataset",
            "probability": "Medium",
            "mitigation": "Frame project approval as a proxy for donor-supported success and clearly explain this limitation"
        }
    ],

    "terminology": {
        "Project Approval": "A funded or accepted DonorsChoose project, used here as the main target variable",
        "Segmentation": "The process of identifying meaningful patterns or groups within data to support decision-making",
        "Donor Retention Strategy": "An evidence-based approach used by non profit organisations to maintain donor engagement over time",
        "Classification": "A machine learning task used to predict categorical outcomes such as approved or not approved"
    },

    "cost_benefit": "The cost of implementing a data driven approach is relatively low because it mainly requires open-source tools and a public dataset, while the potential benefit is improved understanding of the project characteristics that attract donor support and can inform future donor engagement strategies."
}

# %%
# Display situation assessment
import json
print(json.dumps(situation_assessment, indent=2))
# Out:
# {
#   "resources": {
#     "personnel": [
#       "Individual student researcher",
#       "Domain knowledge from academic articles and module materials"
#     ],
#     "data_sources": [
#       "DonorsChoose Application Screening dataset from Kaggle"
#     ],
#     "computing": "Local machine with Anaconda environment and Jupyter Notebook support",
#     "software": [
#       "Python",
#       "pandas",
#       "NumPy",
#       "scikit-learn",
#       "matplotlib",
#       "seaborn"
#     ]
#   },
#   "requirements": [
#     "Access to a sufficiently large dataset related to non-profit project funding",
#     "Ability to preprocess structured and categorical data for modelling",
#     "Compliance with ethical and privacy considerations when working with public datasets"
#   ],
#   "assumptions": [
#     "The DonorsChoose dataset is representative of project funding patterns in a non-profit context",
#     "Project approval can be used as an indicator of successful donor support",
# ...

# %%
# Optional: Add any further notes or elaboration on the situation assessment

# %% [markdown]
# ---
# ### Task 3: Determine Data Mining Goals
#
# A business goal states objectives in business terminology. A data mining goal states project objectives in technical terms. This task converts the business objectives identified in Task 1 into specific, measurable data mining goals:
#
# - **Data Mining Problem Type:** Classify the problem (e.g., classification, regression, clustering, anomaly detection, association rule mining, etc.).
# - **Data Mining Goals:** State the technical objectives clearly (e.g., "Build a classification model to predict [target variable] with an F1-score ≥ 0.85").
# - **Data Mining Success Criteria:** Define the technical metrics that will be used to evaluate the model's performance (e.g., accuracy, precision, recall, RMSE, silhouette score).
#
# **Instructions:** Map your business objectives to concrete data mining goals.

# %%
# TODO: Define data mining goals here.

data_mining_goals = {
    "problem_type": "Binary Classification",

    "target_variable": "project_is_approved",

    "technical_goals": [
        "Build a classification model to predict whether a project will be approved ",
        "Identify the most important features that influence project approval outcomes",
        "Analyse how project characteristics, like cost and category, impact funding success",
        "Evaluate model performance using appropriate classification metrics"
    ],

    "success_metrics": [
        "Accuracy",
        "Precision",
        "Recall",
        "F1-Score",
        "ROC-AUC"
    ],

    "tools": [
        "Python",
        "pandas",
        "NumPy",
        "scikit-learn",
        "matplotlib",
        "seaborn"
    ],

    "techniques": [
        "Logistic Regression",
        "Random Forest",
        "Gradient Boosting"
    ],

    "timeline": [
        {"phase 1": "Data Understanding", "duration": "Week 3–4", "status": "Planned"},
        {"phase 2": "Data Preparation", "duration": "Week 5–6", "status": "Planned"},
        {"phase 3": "Modeling", "duration": "Week 7–8", "status": "Planned"},
        {"phase 4": "Evaluation", "duration": "Week 8–9", "status": "Planned"},
        {"phase 5": "Deployment/Reporting", "duration": "Week 10–11", "status": "Planned"}
    ],

    "dependencies": [
        "Dataset must be available before modeling begins",
        "Cleaned and preprocessed data is required before training models"
    ],

    "tool_justification": "Python is selected due to its strong ecosystem for data science and machine learning. Libraries such as pandas enable efficient data manipulation, while scikit-learn supports classification modeling. Visualization tools like matplotlib and seaborn help interpret patterns and insights. These tools are widely used in industry and suitable for analysing moderately large datasets."
}

# %%
# Display the mapping from business objectives to data mining goals
print("=" * 60)
print("BUSINESS TO DATA MINING GOAL MAPPING")
print("=" * 60)
print(f"\nBusiness Objective : {business_objectives['primary_objective']}")
print(f"Problem Type       : {data_mining_goals['problem_type']}")
print(f"Target Variable    : {data_mining_goals['target_variable']}")
print(f"\nTechnical Goals:")
for goal in data_mining_goals['technical_goals']:
    print(f"  - {goal}")
print(f"\nSuccess Metrics:")
for metric in data_mining_goals['success_metrics']:
    print(f"  - {metric}")
# Out:
# ...
# BUSINESS TO DATA MINING GOAL MAPPING
# ...
#
# Business Objective : To analyse the factors that influence whether a project is approved (funded) and use these insights to support donor segmentation and retention strategies by identifying the types of projects that are more likely to attract consistent donor support.
# Problem Type       : Binary Classification
# Target Variable    : project_is_approved
#
# Technical Goals:
#   - Build a classification model to predict whether a project will be approved
#   - Identify the most important features that influence project approval outcomes
#   - Analyse how project characteristics, like cost and category, impact funding success
#   - Evaluate model performance using appropriate classification metrics
#
# Success Metrics:
#   - Accuracy
#   - Precision
#   - Recall
#   - F1-Score
#   - ROC-AUC

# %% [markdown]
# ---
# ### Task 4: Produce Project Plan
#
# Describe the intended plan for achieving the data mining goals and thereby achieving the business goals. The plan should specify:
#
# - **Tools and Techniques:** The data mining tools (libraries, frameworks) and modelling techniques you plan to use.
# - **Project Plan / Timeline:** A step-by-step plan with estimated durations for each remaining CRISP-DM phase.
# - **Dependencies:** Any dependencies between tasks or on external factors.
# - **Initial Assessment of Tools and Techniques:** A brief justification for why the chosen tools and techniques are appropriate.
#
# **Instructions:** Outline your full project plan as a structured data object below.

# %%
# TODO: Produce your project plan here.

project_plan = {
    "tools": ["Python", "pandas", "NumPy", "scikit-learn", "matplotlib", "seaborn", "Jupyter Notebook"],

    "techniques": [
        "Exploratory Data Analysis (EDA)",
        "Logistic Regression",
        "Random Forest",
        "Gradient Boosting"
    ],

    "timeline": [
        {"phase": "Data Understanding", "duration": "Week 3–4", "status": "Completed"},
        {"phase": "Data Preparation", "duration": "Week 5–6", "status": "Completed"},
        {"phase": "Modeling", "duration": "Week 7–8", "status": "Completed"},
        {"phase": "Evaluation", "duration": "Week 8–9", "status": "In Progress"},
        {"phase": "Deployment/Reporting", "duration": "Week 9–11", "status": "Pending"}
    ],

    "dependencies": [
        "Access to dataset",
        "Completion of preprocessing before modeling",
        "Model training must be completed before evaluation",
        "Evaluation results required before final reporting"
    ],

    "tool_justification": "The selected tools are well-suited for analysing structured datasets such as the DonorsChoose project data. Python provides a flexible environment for data preprocessing, modeling, and visualization. Libraries like pandas and NumPy enable efficient data handling, while scikit-learn supports the implementation of classification algorithms such as Logistic Regression, Random Forest, and Gradient Boosting. Visualization tools such as matplotlib and seaborn help interpret patterns and communicate insights effectively, which is essential for supporting donor-related decision-making."
}

# %%
# Display the project plan

print("PROJECT PLAN: ")


print("\nTools:", ", ".join(project_plan['tools']) if project_plan['tools'] else "[Not yet defined]")
print("Techniques:", ", ".join(project_plan['techniques']) if project_plan['techniques'] else "[Not yet defined]")

print("\nTimeline:")
if project_plan['timeline']:
    for phase in project_plan['timeline']:
        print(f"  [{phase.get('status', 'N/A'):^12}] {phase['phase']:<25} | {phase['duration']}")
else:
    print("  [Not yet defined]")

print("\nDependencies:")
for dep in project_plan['dependencies']:
    print(f"  - {dep}")

print(f"\nTool Justification: {project_plan['tool_justification']}")
# Out:
# PROJECT PLAN:
#
# Tools: Python, pandas, NumPy, scikit-learn, matplotlib, seaborn, Jupyter Notebook
# Techniques: Exploratory Data Analysis (EDA), Logistic Regression, Random Forest, Gradient Boosting
#
# Timeline:
#   [ Completed  ] Data Understanding        | Week 3–4
#   [ Completed  ] Data Preparation          | Week 5–6
#   [ Completed  ] Modeling                  | Week 7–8
#   [In Progress ] Evaluation                | Week 8–9
#   [  Pending   ] Deployment/Reporting      | Week 9–11
#
# Dependencies:
#   - Access to dataset
#   - Completion of preprocessing before modeling
#   - Model training must be completed before evaluation
#   - Evaluation results required before final reporting
#
# ...

# %%
# Optional: Summarise all Phase 1 outputs for reference in subsequent phases
print("=" * 60)
print("PHASE 1 SUMMARY: BUSINESS UNDERSTANDING")
print("=" * 60)
print(f"\nPrimary Objective  : {business_objectives['primary_objective']}")
print(f"Problem Type       : {data_mining_goals['problem_type']}")
print(f"Target Variable    : {data_mining_goals['target_variable']}")
print(f"Tools Planned      : {', '.join(project_plan['tools']) if project_plan['tools'] else 'TBD'}")
print(f"Techniques Planned : {', '.join(project_plan['techniques']) if project_plan['techniques'] else 'TBD'}")
# Out:
# ...
# PHASE 1 SUMMARY: BUSINESS UNDERSTANDING
# ...
#
# Primary Objective  : To analyse the factors that influence whether a project is approved (funded) and use these insights to support donor segmentation and retention strategies by identifying the types of projects that are more likely to attract consistent donor support.
# Problem Type       : Binary Classification
# Target Variable    : project_is_approved
# Tools Planned      : Python, pandas, NumPy, scikit-learn, matplotlib, seaborn, Jupyter Notebook
# Techniques Planned : Exploratory Data Analysis (EDA), Logistic Regression, Random Forest, Gradient Boosting
